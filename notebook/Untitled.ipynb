# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

import os
import sys
import pandas as pd

import pickle
import glob
import re
import yaml
import torch
import json

# %%
N = 100
theta = torch.FloatTensor(N)

for i in range(N):
    theta[i] = i / N * math.pi
    
x = theta + (theta * 2).sin() / 2
y = theta.sin().pow(2)

# %%
plt.plot(x.numpy(), y.numpy())
